# %%
import pandas as pd

# %%
orders = pd.read_table('http://bit.ly/chiporders')
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
user_cols = ['user_id', 'age', 'gender', 'zip_code']
users = pd.read_csv('http://bit.ly/movieusers', delimiter='|', header = None, names = user_cols)

# %%
users.head()
# Out:
#    user_id age      gender zip_code
# 1       24   M  technician    85711
# 2       53   F       other    94043
# 3       23   M      writer    32067
# 4       24   M  technician    43537
# 5       33   F       other    15213

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['New'] = ufo['City'] + " , " + ufo['State']

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                          New
# 0                Ithaca , NY
# 1           Willingboro , NJ
# 2               Holyoke , CO
# 3               Abilene , KS
# 4  New York Worlds Fair , NY

# %%
ufo.City.sort_values()
# Out:
# 1761                               Abbeville
# 4553                                Aberdeen
# 16167                               Aberdeen
# 14703                               Aberdeen
# 389                                 Aberdeen
# 12294                               Aberdeen
# 17809                               Aberdeen
# 9404                                Aberdeen
# 2297                                Aberdeen
# 8357                                 Abilene
# 3                                    Abilene
# 10883                                Abilene
# 6654                                 Abilene
# 8783                                 Abilene
# 6621                                Abingdon
# 10861                               Abingdon
# 12229                                 Acampo
# 6164                                Accokeek
# 3534                                  Accord
# 705                                    Acoma
# 7263                                   Acton
# ...

# %%
 UFO =ufo.sort_values(['Shape Reported', 'State'], ascending = False)

# %%
UFO.head()
# Out:
#              City Colors Reported Shape Reported State             Time  \
# 7183      Laramie             NaN        VARIOUS    WY  8/23/1993 19:56
# 3833   Morgantown             NaN        VARIOUS    WV   7/4/1978 23:00
# 15841  St. Albans             NaN        VARIOUS    WV    2/6/2000 6:30
# 2889    Milwaukee             NaN        VARIOUS    WI   6/1/1975 15:00
# 11100   Milwaukee             NaN        VARIOUS    WI   1/1/1998 23:00
#
#                    New
# 7183      Laramie , WY
# 3833   Morgantown , WV
# 15841  St. Albans , WV
# 2889    Milwaukee , WI
# 11100   Milwaukee , WI

# %%
booleans = []
for state in UFO.State:
    if state == 'WI':
        booleans.append(True)
    else:
        booleans.append(False)

# %%
booleans[:5]
# Out:
# [False, False, False, True, True]

# %%
is_WI = pd.Series(booleans)

# %%
is_WI.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
is_WI = UFO.State == "WI"
is_WI.head()
# Out:
# 7183     False
# 3833     False
# 15841    False
# 2889      True
# 11100     True
# Name: State, dtype: bool

# %%
UFO[is_WI]['Shape Reported']
UFO.loc[(is_WI) & (UFO['Shape Reported'] == 'TRIANGLE'),]
# Out:
#                   City Colors Reported Shape Reported State              Time  \
# 2954          Kimberly             NaN       TRIANGLE    WI    6/30/1975 3:00
# 2981          Mt. Hope             NaN       TRIANGLE    WI   7/11/1975 20:00
# 2990         Green Bay             NaN       TRIANGLE    WI   7/15/1975 16:00
# 3347           Kenosha             NaN       TRIANGLE    WI   8/15/1976 21:00
# 3674           Muscoda             RED       TRIANGLE    WI  12/17/1977 19:30
# 4157       New Londons             NaN       TRIANGLE    WI   8/10/1979 21:45
# 4357          Caldwell             NaN       TRIANGLE    WI     7/1/1980 1:00
# 4868           Oshkosh             NaN       TRIANGLE    WI    4/23/1983 8:30
# 4869           Oshkosh             NaN       TRIANGLE    WI   4/23/1983 20:30
# 5453           Chilton             NaN       TRIANGLE    WI   6/15/1986 13:00
# 5763        Reedsville             NaN       TRIANGLE    WI  11/15/1987 22:00
# ...

# %%
UFO.City.duplicated().sum()
# Out:
# 11764

# %%
UFO1 = UFO[UFO.duplicated(subset = ['City', 'Shape Reported'])]

# %%
UFO1.sort_values(['City','Shape Reported'])
# Out:
#              City Colors Reported Shape Reported State              Time  \
# 17809    Aberdeen           GREEN       FIREBALL    WA  10/29/2000 17:25
# 2297     Aberdeen             NaN       TRIANGLE    MD    8/18/1972 1:30
# 8783      Abilene             NaN            NaN    KS  10/14/1995 23:20
# 1539          Ada             NaN         CIRCLE    OK  10/31/1967 20:30
# 10386       Akron             NaN           DISK    OH   6/15/1997 18:00
# 3380        Akron             NaN          LIGHT    OH   9/25/1976 22:00
# 5807        Akron             NaN          LIGHT    OH    4/4/1988 23:30
# 14277       Akron             NaN          LIGHT    MI   8/20/1999 22:00
# 17369  Alamogordo             NaN           DISK    NM    9/9/2000 20:30
# 7008   Alamogordo             NaN          LIGHT    NM   4/21/1993 19:30
# 10423     Alamosa             RED          LIGHT    CO   6/20/1997 21:45
# 13838     Alamosa             NaN          LIGHT    CO    7/3/1999 21:20
# ...

# %%
UFO.groupby('State').City.agg(['count',]).head()
# Out:
#        count
# State
# AK       116
# AL       193
# AR       206
# AZ       736
# CA      2525

# %%
# %matplotlib inline

# %%
UFO.groupby('State').City.agg(['count',]).plot(kind='bar')
